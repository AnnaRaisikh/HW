# %% [markdown]
# # Задачи по Эконометрике: Гетероскедастичность

# %% [markdown]
# 1 Тесты
# 1.1 sleep equation

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ryupepa/Econometrica/master/python-notebooks/data-csv/sleep75.csv')

# %%
model = smf.ols(data=df, formula='sleep~totwrk+age+I(age**2)+male+smsa+south').fit()

# %%
df['res2']=model.resid**2
df['res']=model.resid

# %%
df
# Out:
#      age  black  case  clerical  construc  educ  earns74  gdhlth  inlf  leis1  \
# 0     32      0     1  0.000000  0.000000    12        0       0     1   3529
# 1     31      0     2  0.000000  0.000000    14     9500       1     1   2140
# 2     44      0     3  0.000000  0.000000    17    42500       1     1   4595
# 3     30      0     4  0.000000  0.000000    12    42500       1     1   3211
# 4     64      0     5  0.000000  0.000000    14     2500       1     1   4052
# ..   ...    ...   ...       ...       ...   ...      ...     ...   ...    ...
# 701   45      0   702  0.182331  0.030075    12     5500       1     0   5069
# 702   34      0   703  0.182331  0.030075    10     2500       0     0   5885
# 703   37      0   704  0.182331  0.030075    12     3500       1     0   4719
# 704   54      0   705  0.182331  0.030075    17    32500       1     0   5149
# 705   30      0   706  0.182331  0.030075    16     6750       1     0   4747
#
# ...

# %%
 sub_model= smf.ols(data=df, formula='res2~totwrk+age+I(age**2)+male+smsa+south').fit()

# %%
sub_model.rsquared
# Out:
# 0.011770584003290452

# %%
St = np.round(len(df)*sub_model.rsquared,2)
St
# Out:
# 8.31

# %%
Hi2 = stats.chi2.ppf(1-0.05,6)
Hi2
# Out:
# 12.591587243743977

# %% [markdown]
# $$R^2<Xp^2$$
#  Нет оснований отвергнуть нулевую гипотезу. Тест указывает на гомоскедастичность

# %% [markdown]
# # 1.2 wage equation

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ryupepa/Econometrica/master/python-notebooks/data-csv/wage1.csv')

# %%
model = smf.ols(data=df, formula='np.log(wage)~exper+I(exper**2)+female+married+smsa').fit()

# %%
df['res2']=model.resid**2
df['res']=model.resid

# %%
df
# Out:
#       wage  educ  exper  tenure  nonwhite  female  married  numdep  smsa  \
# 0     3.10    11      2       0         0       1        0       2     1
# 1     3.24    12     22       2         0       1        1       3     1
# 2     3.00    11      2       0         0       0        0       2     0
# 3     6.00     8     44      28         0       0        1       0     1
# 4     5.30    12      7       2         0       0        1       1     0
# ..     ...   ...    ...     ...       ...     ...      ...     ...   ...
# 521  15.00    16     14       2         0       1        1       2     0
# 522   2.27    10      2       0         0       1        0       3     0
# 523   4.67    15     13      18         0       0        1       3     0
# 524  11.56    16      5       1         0       0        1       0     0
# 525   3.50    14      5       4         1       1        0       2     0
#
#      northcen  ...  services  profserv  profocc  clerocc  servocc     lwage  \
# ...

# %%
 sub_model= smf.ols(data=df, formula='res2~exper+I(exper**2)+female+married+smsa').fit()

# %%
sub_model.rsquared
# Out:
# 0.01699592733210531

# %%
St = np.round(len(df)*sub_model.rsquared,2)
St
# Out:
# 8.94

# %%
Hi2 = stats.chi2.ppf(1-0.05,5)
Hi2
# Out:
# 11.070497693516351

# %% [markdown]
# $$R^2<Xp^2$$
#  Нет оснований отвергнуть нулевую гипотезу. Тест указывает на гомоскедастичность

# %% [markdown]
# # 1.3 output equation

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ryupepa/Econometrica/master/python-notebooks/data-csv/Labour.csv')
df
# Out:
#        capital  labour     output       wage
# 0     2.606563     184   9.250759  43.080307
# 1     1.323237      91   3.664310  27.780016
# 2    22.093692     426  28.781516  44.467748
# 3    10.737851      72   4.124642  39.734710
# 4     1.161365      46   2.890150  34.650709
# ..         ...     ...        ...        ...
# 564   2.625403      20   1.424376  33.477545
# 565   1.276386      61   2.109048  26.300732
# 566   1.953869     117   6.241870  41.153979
# 567   1.318527      46   7.902237  66.720139
# 568   2.832391     161   6.804085  36.618435
#
# [569 rows x 4 columns]

# %%
modelone = smf.ols(data=df, formula='np.log(output)~np.log(capital)+np.log(labour)+I(np.log(capital)**2)+I(np.log(labour)**2)').fit()

# %%
df['res2']=model1.resid**2
df['res']=model1.resid
df
# Out:
#        capital  labour     output       wage      res2       res
# 0     2.606563     184   9.250759  43.080307  0.008845  0.094046
# 1     1.323237      91   3.664310  27.780016  0.035053 -0.187225
# 2    22.093692     426  28.781516  44.467748  0.000268  0.016362
# 3    10.737851      72   4.124642  39.734710  0.173285 -0.416276
# 4     1.161365      46   2.890150  34.650709  0.004548  0.067439
# ..         ...     ...        ...        ...       ...       ...
# 564   2.625403      20   1.424376  33.477545  0.070649 -0.265799
# 565   1.276386      61   2.109048  26.300732  0.208491 -0.456608
# 566   1.953869     117   6.241870  41.153979  0.007905  0.088908
# 567   1.318527      46   7.902237  66.720139  1.099995  1.048807
# 568   2.832391     161   6.804085  36.618435  0.018350 -0.135462
#
# [569 rows x 6 columns]

# %%
 sub_model1= smf.ols(data=df, formula='res2~np.log(capital)+np.log(labour)+I(np.log(capital)**2)+I(np.log(labour)**2)').fit()

# %%
sub_model.rsquared
# Out:
# 0.07826664061234878

# %%
St = np.round(len(df)*sub_model1.rsquared,2)
St
# Out:
# 44.53

# %%
Hi2 = stats.chi2.ppf(1-0.05,4)
Hi2
# Out:
# 9.487729036781154

# %% [markdown]
# $$R^2>Xp^2$$
#  Есть основания отвергнуть нулевую гипотезу. Тест указывает на гетероскедастичность

# %% [markdown]
# # 1.4 cost equation #1

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ryupepa/Econometrica/master/python-notebooks/data-csv/Electricity.csv')
df
# Out:
#         cost        q        pl      sl      pk      sk      pf      sf
# 0     0.2130      8.0   6869.47  0.3291  64.945  0.4197  18.000  0.2512
# 1     3.0427    869.0   8372.96  0.1030  68.227  0.2913  21.067  0.6057
# 2     9.4059   1412.0   7960.90  0.0891  40.692  0.1567  41.530  0.7542
# 3     0.7606     65.0   8971.89  0.2802  41.243  0.1282  28.539  0.5916
# 4     2.2587    295.0   8218.40  0.1772  71.940  0.1623  39.200  0.6606
# ..       ...      ...       ...     ...     ...     ...     ...     ...
# 153   6.8293    946.6  10642.16  0.0883  43.600  0.1914  51.463  0.7203
# 154   3.7605    377.0   7432.24  0.2117  74.120  0.2274  33.436  0.5609
# 155   3.9822    391.0   5826.04  0.1926  78.288  0.0924  44.633  0.7151
# 156  30.1880   5317.0   9586.63  0.0845  78.008  0.2009  41.840  0.7147
# 157  67.8562  15220.0   6986.09  0.1451  74.025  0.2596  25.662  0.5945
#
# [158 rows x 8 columns]

# %%
model = smf.ols(data=df, formula='np.log(cost)~np.log(q)+I(np.log(q)**2)+np.log(pl)+np.log(pk)+np.log(pf)').fit()

# %%
df['res2']=model.resid**2
df['res']=model.resid
df
# Out:
#         cost        q        pl      sl      pk      sk      pf      sf  \
# 0     0.2130      8.0   6869.47  0.3291  64.945  0.4197  18.000  0.2512
# 1     3.0427    869.0   8372.96  0.1030  68.227  0.2913  21.067  0.6057
# 2     9.4059   1412.0   7960.90  0.0891  40.692  0.1567  41.530  0.7542
# 3     0.7606     65.0   8971.89  0.2802  41.243  0.1282  28.539  0.5916
# 4     2.2587    295.0   8218.40  0.1772  71.940  0.1623  39.200  0.6606
# ..       ...      ...       ...     ...     ...     ...     ...     ...
# 153   6.8293    946.6  10642.16  0.0883  43.600  0.1914  51.463  0.7203
# 154   3.7605    377.0   7432.24  0.2117  74.120  0.2274  33.436  0.5609
# 155   3.9822    391.0   5826.04  0.1926  78.288  0.0924  44.633  0.7151
# 156  30.1880   5317.0   9586.63  0.0845  78.008  0.2009  41.840  0.7147
# 157  67.8562  15220.0   6986.09  0.1451  74.025  0.2596  25.662  0.5945
#
#          res2       res
# 0    0.088404  0.297328
# 1    0.115198 -0.339409
# 2    0.000105  0.010243
# ...

# %%
 sub_model1= smf.ols(data=df, formula='res2~np.log(q)+I(np.log(q)**2)+np.log(pl)+np.log(pk)+np.log(pf)').fit()

# %%
sub_model1.rsquared
# Out:
# 0.28529228536900797

# %%
St = np.round(len(df)*sub_model1.rsquared,2)
St
# Out:
# 45.08

# %%
Hi2 = stats.chi2.ppf(1-0.05,5)
Hi2
# Out:
# 11.070497693516351

# %% [markdown]
# $$R^2>Xp^2$$
#  Есть основания отвергнуть нулевую гипотезу. Тест указывает на гетероскедастичность

# %% [markdown]
# # 1.5 cost equation #2

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ryupepa/Econometrica/master/python-notebooks/data-csv/Electricity.csv')
df
# Out:
#         cost        q        pl      sl      pk      sk      pf      sf
# 0     0.2130      8.0   6869.47  0.3291  64.945  0.4197  18.000  0.2512
# 1     3.0427    869.0   8372.96  0.1030  68.227  0.2913  21.067  0.6057
# 2     9.4059   1412.0   7960.90  0.0891  40.692  0.1567  41.530  0.7542
# 3     0.7606     65.0   8971.89  0.2802  41.243  0.1282  28.539  0.5916
# 4     2.2587    295.0   8218.40  0.1772  71.940  0.1623  39.200  0.6606
# ..       ...      ...       ...     ...     ...     ...     ...     ...
# 153   6.8293    946.6  10642.16  0.0883  43.600  0.1914  51.463  0.7203
# 154   3.7605    377.0   7432.24  0.2117  74.120  0.2274  33.436  0.5609
# 155   3.9822    391.0   5826.04  0.1926  78.288  0.0924  44.633  0.7151
# 156  30.1880   5317.0   9586.63  0.0845  78.008  0.2009  41.840  0.7147
# 157  67.8562  15220.0   6986.09  0.1451  74.025  0.2596  25.662  0.5945
#
# [158 rows x 8 columns]

# %%
model4 = smf.ols(data=df, formula='np.log(cost)~np.log(q)+I(np.log(q)**2)+np.log(pl)+np.log(pk)+np.log(pf)+I(np.log(pl)**2) + I(np.log(pk)**2) + I(np.log(pf)**2)').fit()

# %%
df['res2']=model.resid**2
df['res']=model.resid
df
# Out:
#         cost        q        pl      sl      pk      sk      pf      sf  \
# 0     0.2130      8.0   6869.47  0.3291  64.945  0.4197  18.000  0.2512
# 1     3.0427    869.0   8372.96  0.1030  68.227  0.2913  21.067  0.6057
# 2     9.4059   1412.0   7960.90  0.0891  40.692  0.1567  41.530  0.7542
# 3     0.7606     65.0   8971.89  0.2802  41.243  0.1282  28.539  0.5916
# 4     2.2587    295.0   8218.40  0.1772  71.940  0.1623  39.200  0.6606
# ..       ...      ...       ...     ...     ...     ...     ...     ...
# 153   6.8293    946.6  10642.16  0.0883  43.600  0.1914  51.463  0.7203
# 154   3.7605    377.0   7432.24  0.2117  74.120  0.2274  33.436  0.5609
# 155   3.9822    391.0   5826.04  0.1926  78.288  0.0924  44.633  0.7151
# 156  30.1880   5317.0   9586.63  0.0845  78.008  0.2009  41.840  0.7147
# 157  67.8562  15220.0   6986.09  0.1451  74.025  0.2596  25.662  0.5945
#
#          res2       res
# 0    0.082389  0.287035
# 1    0.122132 -0.349474
# 2    0.000076 -0.008746
# ...

# %%
 sub_model1= smf.ols(data=df, formula='res2~np.log(q)+I(np.log(q)**2)+np.log(pl)+np.log(pk)+np.log(pf)+I(np.log(pl)**2) + I(np.log(pk)**2) + I(np.log(pf)**2)').fit()

# %%
sub_model1.rsquared
# Out:
# 0.31202193359272024

# %%
St = np.round(len(df)*sub_model1.rsquared,2)
St
# Out:
# 49.3

# %%
Hi2 = stats.chi2.ppf(1-0.05,8)
Hi2
# Out:
# 15.50731305586545

# %% [markdown]
# $$R^2>Xp^2$$
#  Есть основания отвергнуть нулевую гипотезу. Тест указывает на гетероскедастичность
